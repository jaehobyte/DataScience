# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import warnings

warnings.filterwarnings(action='ignore')

# %%
retail_df = pd.read_excel('/content/drive/MyDrive/DataScience/Online_Retail.xlsx',engine='openpyxl')
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
temp_df = retail_df.copy()

# %%
temp_df['Date'] = temp_df['InvoiceDate'].dt.date

# %%
date_df = temp_df.groupby('Date')['InvoiceNo'].count()

# %%
pd.DataFrame(date_df)
# Out:
#             InvoiceNo
# Date
# 2010-12-01       3108
# 2010-12-02       2109
# 2010-12-03       2202
# 2010-12-05       2725
# 2010-12-06       3878
# ...               ...
# 2011-12-05       5331
# 2011-12-06       3365
# 2011-12-07       2438
# 2011-12-08       4940
# 2011-12-09       1632
#
# [305 rows x 1 columns]

# %%
date_df = date_df.reset_index()

# %%
date_df
# Out:
#            Date  InvoiceNo
# 0    2010-12-01       3108
# 1    2010-12-02       2109
# 2    2010-12-03       2202
# 3    2010-12-05       2725
# 4    2010-12-06       3878
# ..          ...        ...
# 300  2011-12-05       5331
# 301  2011-12-06       3365
# 302  2011-12-07       2438
# 303  2011-12-08       4940
# 304  2011-12-09       1632
#
# [305 rows x 2 columns]

# %%
plt.figure(figsize=(15, 8))
plt.plot(date_df['Date'], date_df['InvoiceNo'])

# %%
temp_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date
# ...

# %%
temp_df['Amount'] = temp_df['Quantity'] * temp_df['UnitPrice']

# %%
temp_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# ...

# %%
rfm_df = temp_df.groupby('CustomerID')[['Amount']].sum()

# %%
rfm_df
# Out:
#              Amount
# CustomerID
# 12346.0        0.00
# 12347.0     4310.00
# 12348.0     1797.24
# 12349.0     1757.55
# 12350.0      334.40
# ...             ...
# 18280.0      180.60
# 18281.0       80.82
# 18282.0      176.60
# 18283.0     2094.88
# 18287.0     1837.28
#
# [4372 rows x 1 columns]

# %%
rfm_df.rename(columns={'Amount': 'Monetary'}, inplace=True)

# %%
rfm_df['Frequency'] = temp_df.groupby('CustomerID')[['InvoiceNo']].count()

# %%
rfm_df
# Out:
#             Monetary  Frequency
# CustomerID
# 12346.0         0.00          2
# 12347.0      4310.00        182
# 12348.0      1797.24         31
# 12349.0      1757.55         73
# 12350.0       334.40         17
# ...              ...        ...
# 18280.0       180.60         10
# 18281.0        80.82          7
# 18282.0       176.60         13
# 18283.0      2094.88        756
# 18287.0      1837.28         70
#
# [4372 rows x 2 columns]

# %%
temp_df['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
import datetime

# %%
temp_df.groupby('CustomerID')['Date'].max()
# Out:
# CustomerID
# 12346.0    2011-01-18
# 12347.0    2011-12-07
# 12348.0    2011-09-25
# 12349.0    2011-11-21
# 12350.0    2011-02-02
#               ...
# 18280.0    2011-03-07
# 18281.0    2011-06-12
# 18282.0    2011-12-02
# 18283.0    2011-12-06
# 18287.0    2011-10-28
# Name: Date, Length: 4372, dtype: object

# %%
rfm_df['Days'] = datetime.date(2011,12,9) - temp_df.groupby('CustomerID')['Date'].max()

# %%
rfm_df
# Out:
#             Monetary  Frequency     Days
# CustomerID
# 12346.0         0.00          2 325 days
# 12347.0      4310.00        182   2 days
# 12348.0      1797.24         31  75 days
# 12349.0      1757.55         73  18 days
# 12350.0       334.40         17 310 days
# ...              ...        ...      ...
# 18280.0       180.60         10 277 days
# 18281.0        80.82          7 180 days
# 18282.0       176.60         13   7 days
# 18283.0      2094.88        756   3 days
# 18287.0      1837.28         70  42 days
#
# [4372 rows x 3 columns]

# %%
rfm_df['Days'] = rfm_df['Days'].dt.days

# %%
rfm_df
# Out:
#             Monetary  Frequency  Days
# CustomerID
# 12346.0         0.00          2   325
# 12347.0      4310.00        182     2
# 12348.0      1797.24         31    75
# 12349.0      1757.55         73    18
# 12350.0       334.40         17   310
# ...              ...        ...   ...
# 18280.0       180.60         10   277
# 18281.0        80.82          7   180
# 18282.0       176.60         13     7
# 18283.0      2094.88        756     3
# 18287.0      1837.28         70    42
#
# [4372 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_df = scaler.fit_transform(rfm_df)

# %%
sns.boxplot(data=rfm_df)
